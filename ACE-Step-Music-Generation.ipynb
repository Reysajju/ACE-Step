# %%
# !git clone https://github.com/ace-step/ACE-Step.git
# %cd ACE-Step
# !pip install -e .
# !acestep --port 7865 --share true --bf16 true --cpu_offload true --overlapped_decode true --torch_compile true
# Out:
# Cloning into 'ACE-Step'...
# remote: Enumerating objects: 760, done.
# remote: Counting objects: 100% (292/292), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 760 (delta 253), reused 199 (delta 199), pack-reused 468 (from 2)
# Receiving objects: 100% (760/760), 10.51 MiB | 14.27 MiB/s, done.
# Resolving deltas: 100% (409/409), done.
# /content/ACE-Step/ACE-Step
# Obtaining file:///content/ACE-Step/ACE-Step
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: datasets==3.4.1 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (3.4.1)
# Requirement already satisfied: diffusers==0.32.2 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.32.2)
# Requirement already satisfied: gradio==5.23.3 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (5.23.3)
# Requirement already satisfied: librosa==0.11.0 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.11.0)
# Requirement already satisfied: loguru==0.7.3 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.7.3)
# Requirement already satisfied: matplotlib==3.10.1 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (3.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (2.0.2)
# Requirement already satisfied: pypinyin==0.53.0 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.53.0)
# Requirement already satisfied: pytorch_lightning==2.5.1 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (2.5.1)
# Requirement already satisfied: soundfile==0.13.1 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.13.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.21.0+cu124)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (4.67.1)
# Requirement already satisfied: transformers==4.50.0 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (4.50.0)
# Requirement already satisfied: py3langid==0.3.0 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.3.0)
# Requirement already satisfied: hangul-romanize==0.1.0 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.1.0)
# Requirement already satisfied: num2words==0.5.14 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.5.14)
# Requirement already satisfied: spacy==3.8.4 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (3.8.4)
# Requirement already satisfied: accelerate==1.6.0 in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (1.6.0)
# Requirement already satisfied: cutlet in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (0.5.0)
# Requirement already satisfied: fugashi[unidic-lite] in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (1.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from ace_step==0.1.1) (8.1.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0->ace_step==0.1.1) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0->ace_step==0.1.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0->ace_step==0.1.1) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0->ace_step==0.1.1) (0.31.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0->ace_step==0.1.1) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets==3.4.1->ace_step==0.1.1) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets==3.4.1->ace_step==0.1.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets==3.4.1->ace_step==0.1.1) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets==3.4.1->ace_step==0.1.1) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets==3.4.1->ace_step==0.1.1) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets==3.4.1->ace_step==0.1.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets==3.4.1->ace_step==0.1.1) (0.70.15)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets==3.4.1->ace_step==0.1.1) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets==3.4.1->ace_step==0.1.1) (3.11.15)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers==0.32.2->ace_step==0.1.1) (8.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers==0.32.2->ace_step==0.1.1) (2024.11.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers==0.32.2->ace_step==0.1.1) (11.2.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.115.12)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.5.0)
# Requirement already satisfied: gradio-client==1.8.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (1.8.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (3.10.18)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (2.11.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.11.9)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.15.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (4.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.23.3->ace_step==0.1.1) (0.34.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (1.5.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->ace_step==0.1.1) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.1->ace_step==0.1.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.1->ace_step==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.1->ace_step==0.1.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.1->ace_step==0.1.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.1->ace_step==0.1.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.1->ace_step==0.1.1) (2.9.0.post0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from num2words==0.5.14->ace_step==0.1.1) (0.6.2)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning==2.5.1->ace_step==0.1.1) (1.7.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning==2.5.1->ace_step==0.1.1) (0.14.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile==0.13.1->ace_step==0.1.1) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy==3.8.4->ace_step==0.1.1) (3.5.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0->ace_step==0.1.1) (0.21.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.8.0->gradio==5.23.3->ace_step==0.1.1) (15.0.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->ace_step==0.1.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->ace_step==0.1.1) (1.3.0)
# Requirement already satisfied: jaconv in /usr/local/lib/python3.11/dist-packages (from cutlet->ace_step==0.1.1) (0.4.0)
# Requirement already satisfied: mojimoji in /usr/local/lib/python3.11/dist-packages (from cutlet->ace_step==0.1.1) (0.0.13)
# Requirement already satisfied: unidic-lite in /usr/local/lib/python3.11/dist-packages (from fugashi[unidic-lite]->ace_step==0.1.1) (1.0.8)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio==5.23.3->ace_step==0.1.1) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio==5.23.3->ace_step==0.1.1) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile==0.13.1->ace_step==0.1.1) (2.22)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.4.1->ace_step==0.1.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.4.1->ace_step==0.1.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.4.1->ace_step==0.1.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.4.1->ace_step==0.1.1) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.4.1->ace_step==0.1.1) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.4.1->ace_step==0.1.1) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.4.1->ace_step==0.1.1) (1.20.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio==5.23.3->ace_step==0.1.1) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio==5.23.3->ace_step==0.1.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==5.23.3->ace_step==0.1.1) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.6.0->ace_step==0.1.1) (1.1.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy==3.8.4->ace_step==0.1.1) (1.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa==0.11.0->ace_step==0.1.1) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==3.4.1->ace_step==0.1.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==3.4.1->ace_step==0.1.1) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa==0.11.0->ace_step==0.1.1) (4.3.8)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio==5.23.3->ace_step==0.1.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio==5.23.3->ace_step==0.1.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio==5.23.3->ace_step==0.1.1) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.1->ace_step==0.1.1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets==3.4.1->ace_step==0.1.1) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets==3.4.1->ace_step==0.1.1) (2.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa==0.11.0->ace_step==0.1.1) (3.6.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy==3.8.4->ace_step==0.1.1) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy==3.8.4->ace_step==0.1.1) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==5.23.3->ace_step==0.1.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==5.23.3->ace_step==0.1.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy==3.8.4->ace_step==0.1.1) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy==3.8.4->ace_step==0.1.1) (7.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers==0.32.2->ace_step==0.1.1) (3.21.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.8.4->ace_step==0.1.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.23.3->ace_step==0.1.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.23.3->ace_step==0.1.1) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy==3.8.4->ace_step==0.1.1) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==5.23.3->ace_step==0.1.1) (0.1.2)
# Installing collected packages: ace_step
#   Attempting uninstall: ace_step
#     Found existing installation: ace_step 0.1.1
#     Uninstalling ace_step-0.1.1:
#       Successfully uninstalled ace_step-0.1.1
#   Running setup.py develop for ace_step
# Successfully installed ace_step-0.1.1
# 2025-05-13 05:42:03.077666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747114923.317337   11201 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747114923.383077   11201 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-13 05:42:03.867012: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# * Running on local URL:  http://127.0.0.1:7865
# * Running on public URL: https://7787b96aa344236385.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2025-05-13 05:43:32.510 | WARNING  | acestep.pipeline_ace_step:__call__:1613 - Checkpoint not loaded, loading checkpoint...
# 2025-05-13 05:43:32.511 | INFO     | acestep.pipeline_ace_step:load_checkpoint:157 - Download models from Hugging Face: ACE-Step/ACE-Step-v1-3.5B, cache to: /root/.cache/ace-step/checkpoints
# Fetching 13 files: 100% 13/13 [00:00<00:00, 126804.54it/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-05-13 05:43:51.686 | INFO     | acestep.pipeline_ace_step:__call__:1619 - Model loaded in 19.18 seconds.
# W0513 05:44:04.213000 11201 torch/_inductor/utils.py:1137] [0/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# 2025-05-13 05:44:46.937 | INFO     | acestep.pipeline_ace_step:text2music_diffusion_process:1006 - cfg_type: apg, guidance_scale: 15, omega_scale: 10
# 2025-05-13 05:44:46.974 | INFO     | acestep.pipeline_ace_step:text2music_diffusion_process:1220 - start_idx: 6, end_idx: 20, num_inference_steps: 27
# 100% 27/27 [01:09<00:00,  2.57s/it]
# Using Overlapped DCAE and Vocoder
#   0% 0/1 [00:00<?, ?it/s]2025-05-13 05:46:18.706 | WARNING  | acestep.pipeline_ace_step:save_wav_file:1531 - save_path is None, using default path ./outputs/
# 2025-05-13 05:46:18.707 | INFO     | acestep.pipeline_ace_step:save_wav_file:1550 - Saving audio to ./outputs/output_20250513054618_0.wav
# 100% 1/1 [00:00<00:00,  4.36it/s]
# 2025-05-13 05:47:41.516 | INFO     | acestep.pipeline_ace_step:text2music_diffusion_process:1006 - cfg_type: apg, guidance_scale: 15, omega_scale: 10
# 2025-05-13 05:47:41.517 | INFO     | acestep.pipeline_ace_step:text2music_diffusion_process:1220 - start_idx: 32, end_idx: 96, num_inference_steps: 128
# 255it [09:28,  2.23s/it]
# Using Overlapped DCAE and Vocoder
#   0% 0/1 [00:00<?, ?it/s]2025-05-13 05:57:29.079 | WARNING  | acestep.pipeline_ace_step:save_wav_file:1531 - save_path is None, using default path ./outputs/
# 2025-05-13 05:57:29.079 | INFO     | acestep.pipeline_ace_step:save_wav_file:1550 - Saving audio to ./outputs/output_20250513055729_0.wav
# 100% 1/1 [00:00<00:00,  5.75it/s]
# 2025-05-13 05:58:04.647 | INFO     | acestep.pipeline_ace_step:text2music_diffusion_process:1006 - cfg_type: apg, guidance_scale: 15, omega_scale: 10
# 2025-05-13 05:58:04.650 | INFO     | acestep.pipeline_ace_step:text2music_diffusion_process:1220 - start_idx: 32, end_idx: 96, num_inference_steps: 128
# 100% 128/128 [05:42<00:00,  2.67s/it]
# Using Overlapped DCAE and Vocoder
#   0% 0/1 [00:00<?, ?it/s]2025-05-13 06:04:05.158 | WARNING  | acestep.pipeline_ace_step:save_wav_file:1531 - save_path is None, using default path ./outputs/
# 2025-05-13 06:04:05.159 | INFO     | acestep.pipeline_ace_step:save_wav_file:1550 - Saving audio to ./outputs/output_20250513060405_0.wav
# 100% 1/1 [00:00<00:00,  5.33it/s]
# 2025-05-13 06:06:30.751 | INFO     | acestep.pipeline_ace_step:__call__:1673 - random audio duration: 87.57411748892055
# 2025-05-13 06:06:32.730 | INFO     | acestep.pipeline_ace_step:text2music_diffusion_process:1006 - cfg_type: apg, guidance_scale: 15, omega_scale: 10
# 2025-05-13 06:06:32.731 | INFO     | acestep.pipeline_ace_step:text2music_diffusion_process:1220 - start_idx: 6, end_idx: 20, num_inference_steps: 27
# 100% 27/27 [01:40<00:00,  3.73s/it]
# Using Overlapped DCAE and Vocoder
#   0% 0/1 [00:00<?, ?it/s]2025-05-13 06:08:39.490 | WARNING  | acestep.pipeline_ace_step:save_wav_file:1531 - save_path is None, using default path ./outputs/
# 2025-05-13 06:08:39.490 | INFO     | acestep.pipeline_ace_step:save_wav_file:1550 - Saving audio to ./outputs/output_20250513060839_0.wav
# 100% 1/1 [00:00<00:00,  3.43it/s]
# Keyboard interruption in main thread... closing server.
#
# Aborted!
# Killing tunnel 127.0.0.1:7865 <> https://7787b96aa344236385.gradio.live
# ^C
